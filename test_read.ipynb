# %%
import pandas as pd

# %%
users = pd.read_csv('users.csv', index_col=0)
users
# Out:
#                 user_id disorder  \
# 0             234244012      mdd
# 1   1136247931592425472      mdd
# 2            1970438215      mdd
# 3   1295880087271886852      mdd
# 4    852685048872673281      mdd
# ..                  ...      ...
# 59   727509081242636292  anxiety
# 60           2852433378  anxiety
# 61  1137178901292208128  anxiety
# 62  1084639601409617920  anxiety
# 63           3946308372  anxiety
#
#                                          anchor_tweet anchor_tweet_date  \
# 0   So I was diagnosed with Major Depressive Disor...        2020-03-30
# 1   i feel like people don’t talk about this enoug...        2020-02-06
# 2   I was diagnosed with major depressive disorder...        2020-03-01
# 3   for everyone who sees this tweet so for a whil...        2020-08-19
# 4   Continue to check on your strong smiling frien...        2018-06-23
# ..                                                ...               ...
# ...

# %%
users.loc[10, 'anchor_tweet']
# Out:
# 'I was an inconsistent hard worker who always crammed to just manage the grades I needed on results day.... until I got to med school at 18, when no amount of effort (+ burnout) could get me the grades I needed. After 18 months struggling, I was diagnosed with #ADHD. \n\n#GetInflow https://t.co/6HPVHOmVxj'
